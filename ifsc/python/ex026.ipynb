# %%
import numpy as np

class VetorNaoOrdenado:
    def __init__(self, capacidade):
        self.capacidade = capacidade
        self.ultima_posicao = -1
        self.valores = np.empty(self.capacidade, dtype=int)

    def imprime(self):
        if self.ultima_posicao == -1:
            print("Valor vazio!")
            return
        
        for i in range(self.ultima_posicao + 1):
            print(f"{i} - {self.valores[i]}")

    def pesquisa(self, alvo):
        for index in self.valores:
            if self.valores[index] == alvo:
                return index

    def inclui(self, valor):
        if self.ultima_posicao >= self.capacidade - 1:
            raise Exception("Limíte de itens excedido.")

        self.ultima_posicao += 1
        self.valores[self.ultima_posicao] = valor

    def exclui(self, valor):
        index_lista = self.pesquisa(valor)

        self.valores = np.delete(self.valores, index_lista)
        self.ultima_posicao -= 1

# %%
vetor = VetorNaoOrdenado(5)

vetor.inclui(4) 
vetor.inclui(6)
vetor.inclui(8)
vetor.inclui(12)
vetor.inclui(5)
# vetor.inclui(9)

vetor.imprime()
print(f"locais com numero 12 {vetor.pesquisa(12)}")

vetor.exclui(12)

vetor.imprime()
# Out:
# 0 - 4
# 1 - 6
# 2 - 8
# 3 - 12
# 4 - 5
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[55], line 11
#       8 # vetor.inclui(9)
#      10 vetor.imprime()
# ---> 11 print(f"locais com numero 12 {vetor.pesquisa(12)}")
#      13 vetor.exclui(12)
#      15 vetor.imprime()
#
# Cell In[54], line 19, in VetorNaoOrdenado.pesquisa(self, alvo)
#      17 def pesquisa(self, alvo):
#      18     for index in self.valores:
# ---> 19         if self.valores[index] == alvo:
#      20             return index
#
# IndexError: index 6 is out of bounds for axis 0 with size 5
